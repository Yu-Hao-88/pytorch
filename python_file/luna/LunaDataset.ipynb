# %%
from vis import findPositiveSamples, showCandidate

positiveSample_list = findPositiveSamples()
# Out:
# 2021-08-29 07:38:13,476 INFO     pid:22448 dsets:181:__init__ <dsets.LunaDataset object at 0x0000017235CA15F8>: 495958 training samples
# 0 CandidateInfoTuple(isNodule_bool=True, diameter_mm=30.61040636, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.112740418331256326754121315800', center_xyz=(47.90350511, 37.60442008, -99.93417567))
# 1 CandidateInfoTuple(isNodule_bool=True, diameter_mm=30.61040636, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.112740418331256326754121315800', center_xyz=(44.19, 37.79, -107.01))
# 2 CandidateInfoTuple(isNodule_bool=True, diameter_mm=30.61040636, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.112740418331256326754121315800', center_xyz=(40.69, 32.19, -97.15))
# 3 CandidateInfoTuple(isNodule_bool=True, diameter_mm=27.44242293, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.943403138251347598519939390311', center_xyz=(-45.29440163, 74.86925386, -97.52812481))
# ...

# %%
series_uid = positiveSample_list[0][2] #取得以下在地資料集中，第一個結節樣本的 series_uid

showCandidate(series_uid)
# Out:
# 2021-08-29 07:39:23,251 INFO     pid:22448 dsets:181:__init__ <dsets.LunaDataset object at 0x000001725EF5B0B8>: 819 training samples
# <img src="data:image/png;base64,..." width="2160">
# 1.3.6.1.4.1.14519.5.2.1.6279.6001.112740418331256326754121315800 0 False [0, 1, 2, 3, 4, 5]
